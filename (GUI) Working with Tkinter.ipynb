# %%
#Graphic user interface

import tkinter as tk
from tkinter import *
import tkinter.ttk as ttk
import csv
from tkinter import messagebox
import string
import re
import os


ws = Tk()
ws.title('PORTAL')
ws.geometry('300x400') 
welcome = Label(ws,text='You are welcome to this page',font =('Georgia',14)).grid(row=1,column=2)
ws.configure(background='')
   

def registerb():
    registerb = Toplevel(ws)
    registerb.title('Register')
    global emaily
    global passwordy

    Registration = Label(registerb,text='REGISTRATION',font =('Georgia',20), bg = 'black', fg = 'white')
    Registration.grid(row=0,column=0)
    firstname = Label(registerb, text ='First Name:', font = ('Times', 15), bg = 'black', fg = 'white')    
    firstname.grid(row=1, column = 0)
    firstnamey = Entry(registerb, width = 30)
    firstnamey.grid(row = 1, column = 1)
    middlename = Label(registerb, text ='Middle Name:', font = ('Times', 15), bg = 'black', fg = 'white')
    middlename.grid(row=2, column = 0)
    middlenamey = Entry(registerb, width = 30)      
    middlenamey.grid(row = 2, column = 1)
    lastname = Label(registerb, text ='Last Name:', font = ('Times', 15), bg = 'black', fg = 'white')
    lastname.grid(row=3, column = 0)
    lastnamey = Entry(registerb, width = 30)
    lastnamey.grid(row = 3, column = 1)
    email = Label(registerb,text = 'Email:', font = ('Times',15), bg = 'black', fg = 'white')
    email.grid (row=4,column=0)
    emaily = Entry(registerb,width = 30)
    emaily.grid(row =4,column=1)
    rd= Label(registerb,text = 'Residential Address:', font = ('Times',15), bg = 'black', fg = 'white')
    rd.grid(row=5,column=0)
    rdy= Entry(registerb,width=30)
    rdy.grid(row=5,column=1)
    tp = Label(registerb, text = 'Telephone Number:', font = ('Times',15), bg = 'black', fg = 'white')
    tp.grid(row=6,column=0)
    tpy=Entry(registerb,width=30)
    tpy.grid(row=6,column=1)
    dob= Label (registerb, text= 'Date of Birth:', font = ('Times', 15), bg = 'black', fg = 'white')
    dob.grid(row=7,column =0)
    doby=Entry(registerb,width=20)
    doby.grid(row=7,column =1)
    gender= Label(registerb,text= 'Gender:', font= ('Times',15), bg = 'black', fg = 'white')
    gender.grid(row=8,column=0)
    Var= StringVar()
    Radiobutton0= ttk.Radiobutton(registerb,text='Male',variable=Var,value='Male').grid(row=8,column=1)
    Radiobutton= ttk.Radiobutton(registerb,text='Female', variable=Var,value='Female').grid(row=8,column=2)
    nationality= Label(registerb, text ='Nationality:', font = ('Times',15), bg = 'black', fg = 'white')
    nationality.grid(row=9,column=0)
    n= StringVar()
    nationalityy =ttk.Combobox(registerb,width=20, textvariable = n)
    nationalityy['value']= ['Algeria','Angola','Benin Republic','Botswana','Burkina Faso','Burundi','Cabo Verde','Cameroon','Central African Republic(CAR)',
         'Chad','Comoros','Congo(Democratic Republic of the Congo)']
    nationalityy.grid(row=9,column= 1)
    username = Label(registerb, text = 'Username:', font = ('Times',15), bg = 'black', fg = 'white')
    username.grid(row=10,column = 0)
    usernamey = Entry(registerb,width=30)
    usernamey.grid (row=10,column=1)
    password = Label(registerb,text='password:',font= ('Times',15), bg = 'black', fg = 'white')
    password.grid(row =11, column= 0)
    passwordy= Entry(registerb,width=20)
    passwordy.grid(row=11,column=1)
    password2 = Label(registerb,text = 'Confirm Password:',font = ('Times',15), bg = 'black', fg = 'white')
    password2.grid(row =12, column= 0)
    password2y = Entry(registerb, width =20)
    password2y.grid(row=12, column = 1)
    note1= Label(registerb,text= 'Note, your password must contain these requirements',font=('Times',12))
    note1.grid(row=13,column=1)
    note2= Label(registerb,text = 'Password must be 8 character long',font=('Times',12))
    note2.grid(row=14,column=1)
    note3 = Label(registerb, text='At least one character must be in capital letter',font =('Times',12))
    note3.grid(row=15,column=1)
    note4= Label(registerb, text= 'At least one character must be a digit',font= ('Times',12))
    note4.grid(row=16, column=1)
    note5= Label(registerb,text='At least one of these symbols !,@$%^*£&#',font=('Times', 12))
    note5.grid(row=17,column=1)
    info = Label(registerb, text='')
    info.grid(row=18, column = 2)
    info1 = Label(registerb, text='',bg= 'black', fg= 'white')
    info1.grid(row=6, column = 2)
    info2 = Label(registerb, text='',bg= 'black', fg= 'white')
    info2.grid(row=4, column = 2)

    alphabets = list (string.ascii_letters)
    digits = list (string.digits)
    special_characters = list('!@$%^*£&#')
    with open('Registration.csv', 'w') as f:
        writer = csv.DictWriter(f,['First Name', 'Middle Name', 'Last Name','Email','Residential Address','Telephone Number','Nationality', 'Date of Birth','Gender', 'Username', 'Password'])
        writer.writeheader()  
        
    def submit_key():
        if str(firstnamey.get())=='' or str(middlenamey.get())=='' or str(lastnamey.get())=='' or str(emaily.get())=='' or str(rdy.get())=='' or str(tpy.get())=='' or str(nationalityy.get())=='' or str(doby.get())=='' or str(Var.get())=='' or str(usernamey.get())=='' or str(passwordy.get())=='' or str(password2y.get())=='':
            info.configure(text= "field can't be empty")
            return
        if re.search ('[@.]',str(emaily.get()))!=None:
            print ('email ok')
        else:
            info2.configure(text='invalid Email')
            return
        if re.search('[0-9]',str(tpy.get()))!=None:
               print('Telephone ok')
        else:
            info1.configure(text='invalid Telephone Number')
            return
        if re.search('[value]',str(nationalityy.get()))!=None:
               print('Telephone ok')
        else:
            info.configure(text='invalid input')
            return
                
            
 
        if str(passwordy.get()) == str(password2y.get()):      
            if re.search('[A-Z]',str(passwordy.get()))!=None:
                if  re.search('[0-9]',str(passwordy.get()))!=None:
                    if re.search('[!@$%^£&#]',str(passwordy.get()))!=None:
                        info.configure(text='password ok')
        
                    
                        with open('Registration.csv', 'a') as f:
                            writer = csv.DictWriter(f,['First Name','Middle Name', 'Last Name', 'Email','Residential Address', 'Telephone Number','Nationality','Date of Birth', 'Gender', 'Username', 'Password'])
                            writer.writerow({'First Name':firstnamey.get(),'Middle Name': middlenamey.get(),'Last Name': lastnamey.get(),'Email':emaily.get(),'Residential Address':rdy.get(),'Telephone Number':tpy.get(),'Nationality':nationalityy.get(),'Date of Birth': doby.get(),'Gender':Var.get(),'Username':usernamey.get(),'Password':h})
                            firstnamey.delete(0, END)
                            middlenamey.delete(0, END)
                            lastnamey.delete(0,END)
                            emaily.delete(0, END)
                            rdy.delete(0,END)
                            #Var.delete(0,END)
                            #Radiobutton.delete(0,END)
                            tpy.delete(0,END)
                            doby.delete(0,END)
                            nationalityy.delete(0,END)
                            usernamey.delete(0,END)
                            passwordy.delete(0,END)
                            password2y.delete(0,END)
                            firstnamey.focus()
                            info.configure(text= 'Your record has been saved')
    
                    else:
                        messagebox.showerror(' password must contain a symbol',icon='warning')
                else:
                    messagebox.showerror(' password must contain a digit',icon='warning')
            else:
                messagebox.showerror('password must contain a letter',icon='warning')
        else:
            messagebox.showerror('password are not the same',icon='warning')         

    submit = Button(registerb, text ='Submit', command =submit_key, font =('Times', 10), bg='black', fg = 'white')
    submit.grid(row = 18, column = 3)
    def exitbox():
        exitl2 = messagebox.askquestion(registerb, 'Are you sure you want to exist?',icon='warning')  
        if exitl2 == 'yes':
            registerb.destroy()
    exit2=Button(registerb,text='Exit', font =('Times',10),command=exitbox,bg='black',fg='white')
    exit2.grid(row=18,column=4)
    
register = Button(ws,text ='Registration:',command= registerb, font = ('Times', 15), bg = 'black', fg = 'white')    
register.grid(row=2, column = 2)



ws.mainloop()
